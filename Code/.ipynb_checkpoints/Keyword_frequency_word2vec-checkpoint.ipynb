# %%
import eda_utils as eu
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Scattertext

# %%
corpus_ballmer = pickle.load(open('cleaned_corpus_ball.pickle', 'rb'))

# %%
corpus_nadella = pickle.load(open('cleaned_corpus_nad.pickle', 'rb'))

# %%
df_msft_scatter = eu.scatter_msft_df(corpus_ballmer, corpus_nadella)

# %%
eu.scatterplot(df_msft_scatter)

# %% [markdown]
# ## Changes in Top 10 Words over Time

# %%
corpus_msft = pickle.load(open('cleaned_corpus_msft.pickle', 'rb'))

# %%
df_msft = eu.document_term_matrix_df(corpus_msft, CountVectorizer)

# %%
eu.top_ten_words(corpus_msft, df_msft)
# Out:
#      FY2007                 FY2008                                    \
#          Q3        Q4           Q1          Q2        Q3          Q4
# 0     vista  guidance      product     product  guidance      online
# 1    impact   premium      reserve      office      unit  investment
# 2      rate      term     guidance    guidance     share    guidance
# 3      sale       mix      operate        half     yahoo       share
# 4   product   product         sale        sale    impact      search
# 5  guidance      high         rate        rate    income     service
# 6       mix      rate         unit     operate   operate     clearly
# 7    number     share    aquantive     company      rate        area
# 8     share  consumer       income       drive    online       yahoo
# 9    launch       new  expectation  investment   product        term
#
#         FY2009                                 FY2010                        \
#             Q1         Q2       Q3       Q4        Q1          Q2        Q3
# 0       margin    expense  product    start     start    consumer    launch
# 1     guidance       half     rate  expense      cost        i've      cost
# 2         cost       cost   remain     cost      side        side     cycle
# 3          low      share    start   impact      term     product   product
# 4         high    annuity  decline  product  consumer        cost      i've
# 5  environment  certainly     cost     sale    demand      attach    office
# 6         term    decline      new     back    attach  enterprise  hardware
# 7         sale       rate   impact  decline  calendar       drive    online
# 8     economic     number      low     term   clearly        flat      sort
# 9       impact   consumer  annuity     half    people       cycle  consumer
#
#                    FY2011                                        FY2012  \
#            Q4          Q1        Q2          Q3          Q4          Q1
# 0     product      office    office     service        full       skype
# 1    guidance     product   product      office  enterprise     service
# 2       share       cloud  consumer    customer    customer      office
# 3       great    consumer    launch     product     product        i've
# 4    consumer         new  customer  enterprise        i've  enterprise
# 5      office        high    search        i've     service        xbox
# 6      online  enterprise    kinect       great      office     product
# 7  enterprise    customer   license         new        cost        cost
# 8    customer    momentum      sort        cost       share        sort
# 9        full     service     share        rate        xbox       cloud
#
#                                              FY2013                        \
#           Q2          Q3          Q4             Q1          Q2        Q3
# 0       sort     product         new        service      device    device
# 1      cloud        i've      office         device     surface   service
# 2     impact  enterprise         sql  transactional        sort       new
# 3    product       cloud  enterprise         office   multiyear    office
# 4        new      launch  capability         launch    customer  customer
# 5   consumer     service     service       customer      launch     cloud
# 6    service        high    customer           time  enterprise    impact
# 7        mix     roadmap   multiyear            new        work   product
# 8       i've     reserve       great     enterprise     service      term
# 9  obviously      public       cloud        surface        time     share
#
#                    FY2014                                   FY2015  \
#            Q4          Q1          Q2       Q3        Q4        Q1
# 0     service  commercial       cloud    cloud     cloud     cloud
# 1       cloud      office  commercial   office    device    office
# 2         new       cloud    consumer   device    office  customer
# 3   executive    consumer      office   change  hardware     drive
# 4    consumer     segment      margin  service   service     azure
# 5     surface      device      impact     time     phone   product
# 6      device        xbox   executive  product       new       new
# 7      office     surface        i've      end   product   service
# 8  enterprise      impact    contract     i've      i've    device
# 9    customer    customer     service    value     drive    margin
#
#                                             FY2016                          \
#            Q2          Q3           Q4          Q1          Q2          Q3
# 0       cloud       cloud        cloud       cloud       cloud       cloud
# 1      office      office       office         new    customer      margin
# 2     service    customer     customer     service         new     service
# 3      impact       azure          new  commercial       azure         new
# 4  commercial         new   enterprise     segment      office     segment
# 5      device      impact  opportunity      office      device      office
# 6     product  commercial        phone    customer     service       azure
# 7    customer     service  significant         mix      impact  commercial
# 8        move  enterprise   commercial       azure     segment       gross
# 9       azure    consumer         even  enterprise  commercial    customer
#
#                       FY2017                                          FY2018  \
#               Q4          Q1          Q2          Q3          Q4          Q1
# 0          cloud       cloud       cloud       azure       cloud      margin
# 1       customer    customer      margin       cloud     service     service
# 2         office     service    linkedin     service       azure       cloud
# 3     commercial  commercial     service    customer  commercial    customer
# 4          azure       azure    customer         new    customer       azure
# 5     enterprise         new       gross      margin         new       gross
# 6        service     segment       azure     dynamic      margin         new
# 7        company      margin      office      office       gross    linkedin
# 8          drive      office  commercial  commercial    linkedin  commercial
# 9  transactional  enterprise      impact    linkedin        base      office
#
#                                            FY2019                          \
#            Q2          Q3          Q4          Q1          Q2          Q3
# 0       azure       cloud       cloud       azure       cloud       azure
# 1       cloud       azure       azure       cloud       azure       cloud
# 2     service     service     service  commercial    customer    customer
# 3    customer    customer  commercial    customer  commercial      margin
# 4         new  commercial    customer     service     service     service
# 5      office        data      margin         new       drive  commercial
# 6  commercial      margin        rate      margin    platform         new
# 7      margin     product         new        game         new       drive
# 8    linkedin    linkedin       gross        data      impact       gross
# 9        game        i've       value      office      margin        data
#
#                    FY2020                                        FY2021  \
#            Q4          Q1        Q2        Q3            Q4          Q1
# 0       cloud       cloud     azure      team      customer       azure
# 1       azure    customer  customer     cloud         cloud       cloud
# 2  commercial       azure    margin  customer         azure      impact
# 3    customer       drive     cloud     azure           new    customer
# 4      margin      margin     gross      work          help     service
# 5         new  commercial       new   dynamic          team  commercial
# 6       gross          ai   service    demand        impact        team
# 7        game         new   dynamic      time         drive       value
# 8     service       gross      data   service  yearoveryear      office
# 9       drive     service     drive      even         power         new
#
#
#            Q2
# 0       cloud
# 1    customer
# 2       azure
# 3       drive
# 4      impact
# 5  commercial
# 6      office
# 7        team
# 8     service
# 9      margin

# %% [markdown]
# ## Keyword Frequency (Importance) over Time

# %%
keyword_list1 = ['cloud', 'ai', 'iot', 'saas', 'license', 'piracy', 'hardware', 'shipment']
eu.keyword_frequency(df_msft, keyword_list1)
plt.savefig('../Charts/keyword_frequency_heatmap1.png',dpi=600)

# %%
keyword_list2 = ['commercial', 'consumer', 'margin', 'cost', 'secular', 'differentiate', 'guidance', 'forecast']
eu.keyword_frequency(df_msft, keyword_list2)
plt.savefig('../Charts/keyword_frequency_heatmap2.png',dpi=600)

# %% [markdown]
# ## Wordcloud

# %%
eu.wordcloud(corpus_ballmer)

# %%
eu.wordcloud(corpus_nadella)

# %% [markdown]
# ## Visualizing Word2Vec Word Embeddings using t-SNE

# %% [markdown]
# ### Unigrams

# %%
eu.word2vec_plot(corpus_msft, 100, 20)

# %% [markdown]
# ### Bigrams

# %%
corpus_msft_bi = pickle.load(open('cleaned_corpus_bi_msft.pickle', 'rb'))

# %%
eu.word2vec_plot(corpus_msft_bi, 60, 10)
