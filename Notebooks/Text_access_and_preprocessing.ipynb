# %% [markdown]
# ## Extracting Text from PDF files

# %% [markdown]
# ### Extracting relevant pages of PDF

# %%
import PyPDF2 as pdf

# %%
def relevant_pages(file_name):
    file = open(file_name, 'rb')
    pdf_reader = pdf.PdfFileReader(file)
    pdf_writer = pdf.PdfFileWriter()
    for i in range(3,pdf_reader.getNumPages()-1):
        page_i = pdf_reader.getPage(i)
        pdf_writer.addPage(page_i)
    
    output = open('../Data/Transcripts/Pages.pdf','wb')
    pdf_writer.write(output)
    output.close()

# %% [markdown]
# ### Extracting text from each PDF

# %%
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter
import io
import os

# %%
def text_extractor(file_name):
    '''
    input: file name of an earnings transcript
    output: extracted text from the transcript
    '''  
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
    
    with open(file_name, 'rb') as fh:

        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            page_interpreter.process_page(page)
            
        text = fake_file_handle.getvalue()

    # close open handles
    converter.close()
    fake_file_handle.close()
    
    return text

# %%
directory = r'/Users/mike/Desktop/GitHub Repositories/project4_microsoft_transformation/Data/Transcripts'
msft_earnings_dict_orig = {}
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        msft_earnings_dict_orig[filename[0:-4]] = text_extractor(os.path.join('../Data/Transcripts', filename))
    else:
        continue

# %%
msft_earnings_dict_orig.keys()
# Out:
# dict_keys(['msft_21q2', 'msft_21q1', 'msft_07q3', 'msft_18q4', 'msft_18q1', 'msft_18q3', 'msft_07q4', 'msft_18q2', 'msft_20q1', 'msft_19q4', 'msft_20q2', 'msft_20q3', 'msft_19q3', 'msft_19q2', 'msft_20q4', 'msft_19q1', 'msft_08q4', 'msft_15q1', 'msft_17q3', 'msft_11q4', 'msft_17q2', 'msft_15q2', 'msft_13q4', 'msft_17q1', 'msft_15q3', 'msft_08q2', 'msft_11q3', 'msft_13q1', 'msft_11q2', 'msft_17q4', 'msft_08q3', 'msft_08q1', 'msft_15q4', 'msft_13q2', 'msft_13q3', 'msft_11q1', 'msft_12q4', 'msft_14q2', 'msft_14q3', 'msft_16q1', 'msft_16q3', 'msft_09q4', 'msft_14q1', 'msft_16q2', 'msft_10q4', 'msft_12q2', 'msft_09q1', 'msft_14q4', 'msft_10q1', 'msft_12q3', 'msft_12q1', 'msft_10q3', 'msft_09q2', 'msft_09q3', 'msft_16q4', 'msft_10q2'])

# %% [markdown]
# ## Text Preprocessing

# %%
msft_earnings_dict = msft_earnings_dict_orig.copy()

# %%
msft_earnings_dict_orig['msft_09q2']
# Out:
# "MICROSOFT CORPORATION FQ2 2009 EARNINGS CALL |  JAN 22, 2009\n\nPresentation\n\nUnknown Speaker\n<strong>Operator</strong>\nWelcome to the Microsoft fiscal year 2009 second quarter earnings call. Today’s call is being recorded. If\nyou have any objections, you may disconnect at this time. I would now like to turn the call over to Mr. Bill\nKoefoed, General Manager, Investor Relations. Sir, you may begin.\n<strong>Bill Koefoed</strong>\nThank you, operator, and thanks everyone for joining us a little earlier than normal today for Microsoft’s\nsecond quarter 2009 earnings conference call. We decided to align the timing of the earnings release this\nquarter with the cost management initiatives that we announced this morning. We will talk further about\nthese initiatives later on the call.\nI am delighted today to be joined by Steve Ballmer, our Chief Executive Officer, as well as Chris Liddell,\nSenior Vice President and Chief Financial Officer, Frank Brod, Corporate Vice President and Chief\nAccounting Officer, and John Seethoff, Deputy General Counsel. The format for today’s call will be as\nfollows\nChris will summarize some of the key take-aways for the quarter, as well as address the announcement\nwe made this morning. I’ll then provide details around our second quarter results and then hand it back to\nChris for a more detailed discussion of our business outlook, and then Steve will make some comments.\nAfter that, we’ll take some questions.\nPlease be aware that we filed our Form 10-Q today in conjunction with our earnings release. We have also\nposted our quarterly financial summary slide deck, which is intended to follow the flow of our prepared\nremarks, as well as provided a reconciliation of differences between GAAP and non-GAAP financial\nmeasures that we will talk about today. You can find these documents on the Investor Relations website at\nwww.microsoft.com/msft.\nToday’s call will be webcast live and recorded. Please be aware that if you decide to ask a question, it will\nbe included in both our live transmission as well as any future use of the recording. A replay of the call\nwill be available at the Microsoft Investor Relations web site through the close of business on January 22,\n2010. This conference call report is protected by copyright law and international treaties. Unauthorized\nreproduction or distribution of this report or any portion of it without the express permission of Microsoft\nmay result in civil and criminal penalties.\nWe will be making statements during this call that are forward-looking. These statements are based on\ncurrent expectations and assumptions that are subject to risks and uncertainties. Actual results could\ndiffer materially because of factors discussed in today’s earnings press release, in the comments made\nduring this conference call, and in the risk factors section of our Form 10-Q, our most recent Form 10-K,\nand other reports and filings with the Securities and Exchange Commission. We do not undertake any duty\nto update any forward-looking statement.\nAnd now, I’ll return the call over to Chris.\n<strong>Chris Liddell</strong>\nThanks, Bill, and again thanks to all of you for accommodating our timing changes.\nOur second-quarter results reflect a difficult environment as the global economy continued to deteriorate\nbeyond our expectations, particularly during the month of December. Despite this economic backdrop,\nwe were able to grow revenue and utilize accelerated cost reductions to offset the majority of the\nimpact to the revenue shortfall on operating income. On a segment basis, our client business, being the\nmost severely impacted by the softening economy, declining 8% due to the significant weakness in the\n\nCopyright © 2019 S&P Global Market Intelligence, a division of S&P Global Inc. All Rights reserved.\nspglobal.com/marketintelligence\n\n3\n\n\x0cMICROSOFT CORPORATION FQ2 2009 EARNINGS CALL |  JAN 22, 2009\n\ntraditional PC market sales, partially offset  ...

# %% [markdown]
# ### Remove line breaks and apostrophes

# %%
for tscript in msft_earnings_dict.keys():
    msft_earnings_dict[tscript] = msft_earnings_dict[tscript].replace('\n',' ')
    msft_earnings_dict[tscript] = msft_earnings_dict[tscript].replace("\'s",'')
    msft_earnings_dict[tscript] = msft_earnings_dict[tscript].replace("\'ll",'')
    msft_earnings_dict[tscript] = msft_earnings_dict[tscript].replace("\'re",'')

# %% [markdown]
# ### Remove punctuations

# %%
import string

# %%
for tscript in msft_earnings_dict.keys():
    msft_earnings_dict[tscript] = msft_earnings_dict[tscript].translate(str.maketrans('', '', string.punctuation))

# %% [markdown]
# ### Remove numbers

# %%
import re

# %%
for tscript in msft_earnings_dict.keys():
    msft_earnings_dict[tscript] = re.sub('\w*\d\w*', '', msft_earnings_dict[tscript])

# %%
for tscript in msft_earnings_dict.keys():
    msft_earnings_dict[tscript] = msft_earnings_dict[tscript].replace('strong','')

# %% [markdown]
# ### Tokenization (words)

# %%
import nltk

# %%
for tscript in msft_earnings_dict.keys():
    msft_earnings_dict[tscript] = nltk.word_tokenize(msft_earnings_dict[tscript])

# %% [markdown]
# ### Correct spelling errors

# %%
from spellchecker import SpellChecker

# %%
spell = SpellChecker()

def correct_spellings(text):
    corrected_text = []
    misspelled_words = spell.unknown(text)
    for word in text:
        if word in misspelled_words:
            corrected_text.append(spell.correction(word))
        else:
            corrected_text.append(word)
    return corrected_text

for tscript in msft_earnings_dict.keys():
    msft_earnings_dict[tscript] = correct_spellings(msft_earnings_dict[tscript])

# %%
msft_earnings_dict['msft_09q2']
# Out:
# ['MICROSOFT',
#  'CORPORATION',
#  'EARNINGS',
#  'CALL',
#  'JAN',
#  'Presentation',
#  'Unknown',
#  'Speaker',
#  'Operator',
#  'Welcome',
#  'to',
#  'the',
#  'Microsoft',
#  'fiscal',
#  'year',
#  'second',
#  'quarter',
#  'earnings',
#  'call',
#  'Today',
#  'i',
#  'i',
#  'call',
#  'is',
#  'being',
#  'recorded',
#  'If',
#  'you',
#  'have',
#  'any',
#  'objections',
#  'you',
#  'may',
#  'disconnect',
#  'at',
#  'this',
#  'time',
#  'I',
#  'would',
#  'now',
#  'like',
#  'to',
#  'turn',
#  'the',
#  'call',
#  'over',
#  'to',
#  'Mr',
#  'Bill',
#  'Koefoed',
#  'General',
#  'Manager',
#  'Investor',
#  'Relations',
#  'Sir',
#  'you',
#  'may',
#  'begin',
#  'Bill',
#  'Koefoed',
#  'Thank',
#  'you',
#  'operator',
#  'and',
#  'thanks',
#  'everyone',
#  'for',
#  'joining',
#  'us',
#  'a',
#  'little',
#  'earlier',
#  'than',
#  'normal',
#  'today',
#  'for',
#  'Microsoft',
#  'i',
#  'i',
#  'second',
#  'quarter',
#  'earnings',
#  'conference',
#  'call',
#  'We',
#  'decided',
#  'to',
#  'align',
#  'the',
#  'timing',
#  'of',
#  'the',
#  'earnings',
#  'release',
#  'this',
#  'quarter',
#  'with',
#  'the',
#  'cost',
#  'management',
#  'initiatives',
#  'that',
#  'we',
#  'announced',
#  'this',
#  'morning',
#  'We',
#  'will',
#  'talk',
#  'further',
#  'about',
#  'these',
#  'initiatives',
#  'later',
#  'on',
#  'the',
#  'call',
#  'I',
#  'am',
#  'delighted',
#  'today',
#  'to',
#  'be',
#  'joined',
#  'by',
#  'Steve',
#  'Ballmer',
#  'our',
#  'Chief',
#  'Executive',
#  'Officer',
#  'as',
#  'well',
#  'as',
#  'Chris',
#  'Liddell',
#  'Senior',
#  'Vice',
#  'President',
#  'and',
#  'Chief',
#  'Financial',
#  'Officer',
#  'Frank',
#  'Brod',
#  'Corporate',
#  'Vice',
#  'President',
#  'and',
#  'Chief',
#  'Accounting',
#  'Officer',
#  'and',
#  'John',
#  'Seethoff',
#  'Deputy',
#  'General',
#  'Counsel',
#  'The',
#  'format',
#  'for',
#  'today',
#  'i',
#  'i',
#  'call',
#  'will',
#  'be',
#  'as',
#  'follows',
#  'Chris',
#  'will',
#  'summarize',
#  'some',
#  'of',
#  'the',
#  'key',
#  'takeaways',
#  'for',
#  'the',
#  'quarter',
#  'as',
#  'well',
#  'as',
#  'address',
#  'the',
#  'announcement',
#  'we',
#  'made',
#  'this',
#  'morning',
#  'I',
#  'i',
#  'all',
#  'then',
#  'provide',
#  'details',
#  'around',
#  'our',
#  'second',
#  'quarter',
#  'results',
#  'and',
#  'then',
#  'hand',
#  'it',
#  'back',
#  'to',
#  'Chris',
#  'for',
#  'a',
#  'more',
#  'detailed',
#  'discussion',
#  'of',
#  'our',
#  'business',
#  'outlook',
#  'and',
#  'then',
#  'Steve',
#  'will',
#  'make',
#  'some',
#  'comments',
#  'After',
#  'that',
#  'we',
#  'i',
#  'all',
#  'take',
#  'some',
#  'questions',
#  'Please',
#  'be',
#  'aware',
#  'that',
#  'we',
#  'filed',
#  'our',
#  'Form',
#  'today',
#  'in',
#  'conjunction',
#  'with',
#  'our',
#  'earnings',
#  'release',
#  'We',
#  'have',
#  'also',
#  'posted',
#  'our',
#  'quarterly',
#  'financial',
#  'summary',
#  'slide',
#  'deck',
#  'which',
#  'is',
#  'intended',
#  'to',
#  'follow',
#  'the',
#  'flow',
#  'of',
#  'our',
#  'prepared',
#  'remarks',
#  'as',
#  'well',
#  'as',
#  'provided',
#  'a',
#  'reconciliation',
#  'of',
#  'differences',
#  'between',
#  'GAAP',
#  'and',
#  'nonGAAP',
#  'financial',
#  'measures',
#  'that',
#  'we',
#  'will',
#  'talk',
#  'about',
#  'today',
#  'You',
#  'can',
#  'find',
#  'these',
#  'documents',
#  'on',
#  'the',
#  'Investor',
#  'Relations',
#  'website',
#  'at',
#  'wwwmicrosoftcommsft',
#  'Today',
#  'i',
#  'i',
#  'call',
#  'will',
#  'be',
#  'webcast',
#  'live',
#  'and',
#  'recorded',
#  'Please',
#  'be',
#  'aware',
#  'that',
#  'if',
#  'you',
#  'decide',
#  'to',
#  'ask',
#  'a',
#  'question',
#  'it',
#  'will',
#  'be',
#  'included',
#  'in',
#  'both',
#  'our',
#  'live',
#  'transmission',
#  'as',
#  'well',
#  'as',
#  'any',
#  'future',
#  'use',
#  'of',
#  'the',
#  'recording',
#  'A',
#  'replay',
#  'of',
#  'the',
#  'call',
#  'will',
#  'be',
#  'available',
#  'at',
#  'the',
#  'Microsoft',
#  'Investor',
#  'Relations',
#  'web',
#  'site',
#  'through',
#  'the',
#  'close',
#  'of',
#  'business',
#  'on',
#  'January',
#  'This',
#  'conference',
#  'call',
#  'report',
#  'is',
#  'protected',
#  'by',
#  'copyright',
#  'law',
#  'and',
#  'international',
#  'treaties',
#  'Unauthorized',
#  'reproduction',
#  'or',
#  'distribution',
#  'of',
#  'this',
#  'report',
#  'or',
#  'any',
#  'portion',
#  'of',
#  'it',
#  'without',
#  'the',
#  'express',
#  'permission',
#  'of',
#  'Microsoft',
#  'may',
#  'result',
#  'in',
#  'civil',
#  'and',
#  'criminal',
#  'penalties',
#  'We',
#  'will',
#  'be',
#  'making',
#  'statements',
#  'during',
#  'this',
#  'call',
#  'that',
#  'are',
#  'forwardlooking',
#  'These',
#  'statements',
#  'are',
#  'based',
#  'on',
#  'current',
#  'expectations',
#  'and',
#  'assumptions',
#  'that',
#  'are',
#  'subject',
#  'to',
#  'risks',
#  'and',
#  'uncertainties',
#  'Actual',
#  'results',
#  'could',
#  'differ',
#  'materially',
#  'because',
#  'of',
#  'factors',
#  'discussed',
#  'in',
#  'today',
#  'i',
#  'i',
#  'earnings',
#  'press',
#  'release',
#  'in',
#  'the',
#  'comments',
#  'made',
#  'during',
#  'this',
#  'conference',
#  'call',
#  'and',
#  'in',
#  'the',
#  'risk',
#  'factors',
#  'section',
#  'of',
#  'our',
#  'Form',
#  'our',
#  'most',
#  'recent',
#  'Form',
#  'and',
#  'other',
#  'reports',
#  'and',
#  'filings',
#  'with',
#  'the',
#  'Securities',
#  'and',
#  'Exchange',
#  'Commission',
#  'We',
#  'do',
#  'not',
#  'undertake',
#  'any',
#  'duty',
#  'to',
#  'update',
#  'any',
#  'forwardlooking',
#  'statement',
#  'And',
#  'now',
#  'I',
#  'i',
#  'all',
#  'return',
#  'the',
#  'call',
#  'over',
#  'to',
#  'Chris',
#  'Chris',
#  'Liddell',
#  'Thanks',
#  'Bill',
#  'and',
#  'again',
#  'thanks',
#  'to',
#  'all',
#  'of',
#  'you',
#  'for',
#  'accommodating',
#  'our',
#  'timing',
#  'changes',
#  'Our',
#  'secondquarter',
#  'results',
#  'reflect',
#  'a',
#  'difficult',
#  'environment',
#  'as',
#  'the',
#  'global',
#  'economy',
#  'continued',
#  'to',
#  'deteriorate',
#  'beyond',
#  'our',
#  'expectations',
#  'particularly',
#  'during',
#  'the',
#  'month',
#  'of',
#  'December',
#  'Despite',
#  'this',
#  'economic',
#  'backdrop',
#  'we',
#  'were',
#  'able',
#  'to',
#  'grow',
#  'revenue',
#  'and',
#  'utilize',
#  'accelerated',
#  'cost',
#  'reductions',
#  'to',
#  'offset',
#  'the',
#  'majority',
#  'of',
#  'the',
#  'impact',
#  'to',
#  'the',
#  'revenue',
#  'shortfall',
#  'on',
#  'operating',
#  'income',
#  'On',
#  'a',
#  'segment',
#  'basis',
#  'our',
#  'client',
#  'business',
#  'being',
#  'the',
#  'most',
#  'severely',
#  'impacted',
#  'by',
#  'the',
#  'softening',
#  'economy',
#  'declining',
#  'due',
#  'to',
#  'the',
#  'significant',
#  'weakness',
#  'in',
#  'the',
#  'Copyright',
#  'i',
#  'SP',
#  'Global',
#  'Market',
#  'Intelligence',
#  'a',
#  'division',
#  'of',
#  'SP',
#  'Global',
#  'Inc',
#  'All',
#  'Rights',
#  'reserved',
#  'spglobalcommarketintelligence',
#  'MICROSOFT',
#  'CORPORATION',
#  'EARNINGS',
#  'CALL',
#  'JAN',
#  'traditional',
#  'PC',
#  'market',
#  'sales',
#  'partially',
#  'offset',
#  'by',
#  'the',
#  'record',
#  'growth',
#  'of',
#  'net',
#  'books',
#  'Revenue',
#  'from',
#  'Microsoft',
#  'business',
#  'edition',
#  'and',
#  'server',
#  'and',
#  'tools',
#  'divisions',
#  'were',
#  'a',
#  'combined',
#  'million',
#  'or',
#  'driven',
#  'by',
#  'healthy',
#  'demand',
#  'from',
#  'enterprise',
#  'customers',
#  'while',
#  'the',
#  'transactional',
#  'aspects',
#  'of',
#  'these',
#  'businesses',
#  'were',
#  'impacted',
#  'by',
#  'lower',
#  'PC',
#  'and',
#  'server',
#  'hardware',
#  'unit',
#  'sales',
#  'Our',
#  'online',
#  'services',
#  'business',
#  'revenue',
#  'was',
#  'flat',
#  'although',
#  'online',
#  'advertising',
#  'revenue',
#  'was',
#  'up',
#  'in',
#  'a',
#  'tough',
#  'environment',
#  'and',
#  'entertainment',
#  'and',
#  'devices',
#  'division',
#  'delivered',
#  'revenue',
#  'above',
#  'the',
#  'high',
#  'end',
#  'of',
#  'our',
#  'guidance',
#  'driven',
#  'by',
#  'a',
#  'record',
#  'number',
#  'of',
#  'consumers',
#  'purchasing',
#  'Xbox',
#  'consoles',
#  'during',
#  'the',
#  'holiday',
#  'season',
#  'Against',
#  'the',
#  'backdrop',
#  'of',
#  'a',
#  'deteriorating',
#  'economy',
#  'we',
#  'are',
#  'focused',
#  'on',
#  'the',
#  'need',
#  'for',
#  'fiscal',
#  'discipline',
#  'and',
#  'on',
#  'executing',
#  'in',
#  'the',
#  'areas',
#  'we',
#  'can',
#  'control',
#  'by',
#  'managing',
#  'expenses',
#  'while',
#  'delivering',
#  'on',
#  'the',
#  'next',
#  'wave',
#  'of',
#  'our',
#  'product',
#  'pipeline',
#  'During',
#  'the',
#  'second',
#  'quarter',
#  'as',
#  'the',
#  'economic',
#  'outlook',
#  'continued',
#  'to',
#  'slow',
#  'we',
#  'accelerated',
#  'our',
#  'expense',
#  'reduction',
#  'plan',
#  'These',
#  'actions',
#  'allowed',
#  'us',
#  'to',
#  'deliver',
#  'operating',
#  'expenses',
#  'in',
#  'the',
#  'second',
#  'quarter',
#  'of',
#  'million',
#  'below',
#  'our',
#  'October',
#  'forecast',
#  'However',
#  'today',
#  'we',
#  'have',
#  'also',
#  'announced',
#  'steps',
#  'we',
#  'will',
#  'take',
#  'to',
#  'further',
#  'manage',
#  'our',
#  'cost',
#  'structure',
#  'These',
#  'steps',
#  'include',
#  'a',
#  'reduction',
#  'in',
#  'headcount',
#  'related',
#  'costs',
#  'including',
#  'plans',
#  'to',
#  'reduce',
#  'up',
#  'to',
#  'positions',
#  'in',
#  'the',
#  'areas',
#  'of',
#  'research',
#  'and',
#  'development',
#  'marketing',
#  'sales',
#  'finance',
#  'legal',
#  'human',
#  'resources',
#  'and',
#  'IT',
#  'over',
#  'the',
#  'next',
#  'months',
#  'of',
#  'which',
#  'are',
#  'effected',
#  'today',
#  'There',
#  'will',
#  'be',
#  'no',
#  'pay',
#  'raises',
#  'next',
#  'fiscal',
#  'year',
#  'We',
#  'have',
#  'plans',
#  'to',
#  'significantly',
#  'reduce',
#  'our',
#  'window',
#  'and',
#  'contingent',
#  'staff',
#  'expenses',
#  'We',
#  'i',
#  'all',
#  'also',
#  'be',
#  'looking',
#  'for',
#  'reductions',
#  'in',
#  'marketing',
#  'expenses',
#  'reduced',
#  'capital',
#  'expenditure',
#  'and',
#  'facility',
#  'costs',
#  'as',
#  'well',
#  'as',
#  'tighter',
#  'discretionary',
#  'spending',
#  'including',
#  'significantly',
#  'reduced',
#  'travel',
#  'related',
#  'expenses',
#  'The',
#  'cumulative',
#  'result',
#  'of',
#  'these',
#  'actions',
#  'taken',
#  'during',
#  'the',
#  'quarter',
#  'and',
#  'those',
#  'announced',
#  'today',
#  'will',
#  'result',
#  'in',
#  'operating',
#  'expense',
#  'savings',
#  'of',
#  'billion',
#  'and',
#  'capital',
#  'expenditure',
#  'savings',
#  'of',
#  'million',
#  'lower',
#  'in',
#  'this',
#  'fiscal',
#  'year',
#  'than',
#  'assumed',
#  'in',
#  'our',
#  'July',
#  'guidance',
#  'Lastly',
#  'we',
#  'plan',
#  'to',
#  'manage',
#  'operating',
#  'expenses',
#  'broadly',
#  'flat',
#  'in',
#  'the',
#  'fiscal',
#  'year',
#  'and',
#  'capital',
#  'expenditure',
#  'to',
#  'be',
#  'lower',
#  'year',
#  'over',
#  'year',
#  'While',
#  'we',
#  'are',
#  'managing',
#  'our',
#  'expenses',
#  'tightly',
#  'we',
#  'continue',
#  'investing',
#  'in',
#  'key',
#  'strategic',
#  'opportunities',
#  'which',
#  'will',
#  'fuel',
#  'the',
#  'future',
#  'growth',
#  'of',
#  'the',
#  'company',
#  'We',
#  'have',
#  'a',
#  'product',
#  'pipeline',
#  'and',
#  'are',
#  'bringing',
#  'to',
#  'market',
#  'a',
#  'number',
#  'of',
#  'significant',
#  'product',
#  'releases',
#  'over',
#  'the',
#  'next',
#  'two',
#  'calendar',
#  'years',
#  'With',
#  'those',
#  'high',
#  'level',
#  'themes',
#  'I',
#  'will',
#  'turn',
#  'the',
#  'call',
#  ...]

# %% [markdown]
# ### Remove stop words

# %%
from nltk.corpus import stopwords

# %%
stopwords = set(stopwords.words('english'))

# %%
msft_earnings_dict2 = {}

for tscript in msft_earnings_dict.keys():
    msft_earnings_dict2[tscript] = [word for word in msft_earnings_dict[tscript] if word.lower() not in stopwords]

# %%
len(msft_earnings_dict2['msft_09q2'])
# Out:
# 4705

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from collections import defaultdict
from nltk import pos_tag

# %%
lemmatizer = WordNetLemmatizer()
tag_map = defaultdict(lambda : wordnet.NOUN)
tag_map['V'] = wordnet.VERB 
tag_map['J'] = wordnet.ADJ
tag_map['R'] = wordnet.ADV

# %%
for tscript in msft_earnings_dict2.keys():
    msft_earnings_dict2[tscript] = [lemmatizer.lemmatize(word.lower(), tag_map[tag[0]]) 
                                   for word, tag in pos_tag(msft_earnings_dict2[tscript])]

# %%
for tscript in msft_earnings_dict2.keys():
    msft_earnings_dict2[tscript] = [word for word in msft_earnings_dict2[tscript] if len(word) > 1]

# %%
msft_earnings_dict2['msft_09q2']
# Out:
# ['microsoft',
#  'corporation',
#  'earnings',
#  'call',
#  'jan',
#  'presentation',
#  'unknown',
#  'speaker',
#  'operator',
#  'welcome',
#  'microsoft',
#  'fiscal',
#  'year',
#  'second',
#  'quarter',
#  'earnings',
#  'call',
#  'today',
#  'call',
#  'record',
#  'objection',
#  'may',
#  'disconnect',
#  'time',
#  'would',
#  'like',
#  'turn',
#  'call',
#  'mr',
#  'bill',
#  'koefoed',
#  'general',
#  'manager',
#  'investor',
#  'relation',
#  'sir',
#  'may',
#  'begin',
#  'bill',
#  'koefoed',
#  'thank',
#  'operator',
#  'thanks',
#  'everyone',
#  'join',
#  'little',
#  'early',
#  'normal',
#  'today',
#  'microsoft',
#  'second',
#  'quarter',
#  'earnings',
#  'conference',
#  'call',
#  'decide',
#  'align',
#  'timing',
#  'earnings',
#  'release',
#  'quarter',
#  'cost',
#  'management',
#  'initiative',
#  'announce',
#  'morning',
#  'talk',
#  'initiatives',
#  'later',
#  'call',
#  'delight',
#  'today',
#  'join',
#  'steve',
#  'ballmer',
#  'chief',
#  'executive',
#  'officer',
#  'well',
#  'chris',
#  'liddell',
#  'senior',
#  'vice',
#  'president',
#  'chief',
#  'financial',
#  'officer',
#  'frank',
#  'brod',
#  'corporate',
#  'vice',
#  'president',
#  'chief',
#  'accounting',
#  'officer',
#  'john',
#  'seethoff',
#  'deputy',
#  'general',
#  'counsel',
#  'format',
#  'today',
#  'call',
#  'follow',
#  'chris',
#  'summarize',
#  'key',
#  'takeaway',
#  'quarter',
#  'well',
#  'address',
#  'announcement',
#  'make',
#  'morning',
#  'provide',
#  'detail',
#  'around',
#  'second',
#  'quarter',
#  'result',
#  'hand',
#  'back',
#  'chris',
#  'detailed',
#  'discussion',
#  'business',
#  'outlook',
#  'steve',
#  'make',
#  'comment',
#  'take',
#  'question',
#  'please',
#  'aware',
#  'file',
#  'form',
#  'today',
#  'conjunction',
#  'earnings',
#  'release',
#  'also',
#  'post',
#  'quarterly',
#  'financial',
#  'summary',
#  'slide',
#  'deck',
#  'intend',
#  'follow',
#  'flow',
#  'prepare',
#  'remark',
#  'well',
#  'provide',
#  'reconciliation',
#  'difference',
#  'gaap',
#  'nongaap',
#  'financial',
#  'measure',
#  'talk',
#  'today',
#  'find',
#  'document',
#  'investor',
#  'relation',
#  'website',
#  'wwwmicrosoftcommsft',
#  'today',
#  'call',
#  'webcast',
#  'live',
#  'record',
#  'please',
#  'aware',
#  'decide',
#  'ask',
#  'question',
#  'include',
#  'live',
#  'transmission',
#  'well',
#  'future',
#  'use',
#  'record',
#  'replay',
#  'call',
#  'available',
#  'microsoft',
#  'investor',
#  'relation',
#  'web',
#  'site',
#  'close',
#  'business',
#  'january',
#  'conference',
#  'call',
#  'report',
#  'protect',
#  'copyright',
#  'law',
#  'international',
#  'treaty',
#  'unauthorized',
#  'reproduction',
#  'distribution',
#  'report',
#  'portion',
#  'without',
#  'express',
#  'permission',
#  'microsoft',
#  'may',
#  'result',
#  'civil',
#  'criminal',
#  'penalty',
#  'make',
#  'statement',
#  'call',
#  'forwardlooking',
#  'statement',
#  'base',
#  'current',
#  'expectation',
#  'assumption',
#  'subject',
#  'risk',
#  'uncertainty',
#  'actual',
#  'result',
#  'could',
#  'differ',
#  'materially',
#  'factor',
#  'discuss',
#  'today',
#  'earnings',
#  'press',
#  'release',
#  'comment',
#  'make',
#  'conference',
#  'call',
#  'risk',
#  'factor',
#  'section',
#  'form',
#  'recent',
#  'form',
#  'report',
#  'filing',
#  'security',
#  'exchange',
#  'commission',
#  'undertake',
#  'duty',
#  'update',
#  'forwardlooking',
#  'statement',
#  'return',
#  'call',
#  'chris',
#  'chris',
#  'liddell',
#  'thanks',
#  'bill',
#  'thank',
#  'accommodate',
#  'time',
#  'change',
#  'secondquarter',
#  'result',
#  'reflect',
#  'difficult',
#  'environment',
#  'global',
#  'economy',
#  'continue',
#  'deteriorate',
#  'beyond',
#  'expectation',
#  'particularly',
#  'month',
#  'december',
#  'despite',
#  'economic',
#  'backdrop',
#  'able',
#  'grow',
#  'revenue',
#  'utilize',
#  'accelerated',
#  'cost',
#  'reduction',
#  'offset',
#  'majority',
#  'impact',
#  'revenue',
#  'shortfall',
#  'operate',
#  'income',
#  'segment',
#  'basis',
#  'client',
#  'business',
#  'severely',
#  'impacted',
#  'soften',
#  'economy',
#  'decline',
#  'due',
#  'significant',
#  'weakness',
#  'copyright',
#  'sp',
#  'global',
#  'market',
#  'intelligence',
#  'division',
#  'sp',
#  'global',
#  'inc',
#  'right',
#  'reserve',
#  'spglobalcommarketintelligence',
#  'microsoft',
#  'corporation',
#  'earnings',
#  'call',
#  'jan',
#  'traditional',
#  'pc',
#  'market',
#  'sale',
#  'partially',
#  'offset',
#  'record',
#  'growth',
#  'net',
#  'book',
#  'revenue',
#  'microsoft',
#  'business',
#  'edition',
#  'server',
#  'tool',
#  'division',
#  'combine',
#  'million',
#  'driven',
#  'healthy',
#  'demand',
#  'enterprise',
#  'customer',
#  'transactional',
#  'aspect',
#  'business',
#  'impact',
#  'low',
#  'pc',
#  'server',
#  'hardware',
#  'unit',
#  'sale',
#  'online',
#  'service',
#  'business',
#  'revenue',
#  'flat',
#  'although',
#  'online',
#  'advertising',
#  'revenue',
#  'tough',
#  'environment',
#  'entertainment',
#  'device',
#  'division',
#  'deliver',
#  'revenue',
#  'high',
#  'end',
#  'guidance',
#  'drive',
#  'record',
#  'number',
#  'consumer',
#  'purchase',
#  'xbox',
#  'console',
#  'holiday',
#  'season',
#  'backdrop',
#  'deteriorate',
#  'economy',
#  'focus',
#  'need',
#  'fiscal',
#  'discipline',
#  'execute',
#  'area',
#  'control',
#  'manage',
#  'expense',
#  'deliver',
#  'next',
#  'wave',
#  'product',
#  'pipeline',
#  'second',
#  'quarter',
#  'economic',
#  'outlook',
#  'continue',
#  'slow',
#  'accelerate',
#  'expense',
#  'reduction',
#  'plan',
#  'action',
#  'allow',
#  'deliver',
#  'operating',
#  'expense',
#  'second',
#  'quarter',
#  'million',
#  'october',
#  'forecast',
#  'however',
#  'today',
#  'also',
#  'announce',
#  'step',
#  'take',
#  'manage',
#  'cost',
#  'structure',
#  'step',
#  'include',
#  'reduction',
#  'headcount',
#  'related',
#  'cost',
#  'include',
#  'plan',
#  'reduce',
#  'position',
#  'area',
#  'research',
#  'development',
#  'marketing',
#  'sale',
#  'finance',
#  'legal',
#  'human',
#  'resource',
#  'next',
#  'month',
#  'effect',
#  'today',
#  'pay',
#  'raise',
#  'next',
#  'fiscal',
#  'year',
#  'plan',
#  'significantly',
#  'reduce',
#  'window',
#  'contingent',
#  'staff',
#  'expense',
#  'also',
#  'look',
#  'reduction',
#  'marketing',
#  'expense',
#  'reduce',
#  'capital',
#  'expenditure',
#  'facility',
#  'cost',
#  'well',
#  'tighter',
#  'discretionary',
#  'spending',
#  'include',
#  'significantly',
#  'reduce',
#  'travel',
#  'relate',
#  'expense',
#  'cumulative',
#  'result',
#  'action',
#  'take',
#  'quarter',
#  'announce',
#  'today',
#  'result',
#  'operate',
#  'expense',
#  'saving',
#  'billion',
#  'capital',
#  'expenditure',
#  'saving',
#  'million',
#  'low',
#  'fiscal',
#  'year',
#  'assume',
#  'july',
#  'guidance',
#  'lastly',
#  'plan',
#  'manage',
#  'operating',
#  'expense',
#  'broadly',
#  'flat',
#  'fiscal',
#  'year',
#  'capital',
#  'expenditure',
#  'lower',
#  'year',
#  'year',
#  'managing',
#  'expense',
#  'tightly',
#  'continue',
#  'invest',
#  'key',
#  'strategic',
#  'opportunity',
#  'fuel',
#  'future',
#  'growth',
#  'company',
#  'product',
#  'pipeline',
#  'bring',
#  'market',
#  'number',
#  'significant',
#  'product',
#  'release',
#  'next',
#  'two',
#  'calendar',
#  'year',
#  'high',
#  'level',
#  'theme',
#  'turn',
#  'call',
#  'bill',
#  'detail',
#  'second',
#  'quarter',
#  'bill',
#  'koefoed',
#  'thanks',
#  'chris',
#  'discus',
#  'top',
#  'line',
#  'financial',
#  'business',
#  'momentum',
#  'point',
#  'follow',
#  'revenue',
#  'performance',
#  'business',
#  'unit',
#  'review',
#  'rest',
#  'income',
#  'statement',
#  'growth',
#  'comparison',
#  'relate',
#  'comparable',
#  'quarter',
#  'last',
#  'year',
#  'unless',
#  'otherwise',
#  'note',
#  'revenue',
#  'grow',
#  'billion',
#  'low',
#  'end',
#  'guidance',
#  'economic',
#  'environment',
#  'weaken',
#  'expect',
#  'particularly',
#  'month',
#  'december',
#  'mix',
#  'product',
#  'billing',
#  'approximately',
#  'oems',
#  'multi',
#  'year',
#  'licensing',
#  'agreement',
#  'license',
#  'sale',
#  'balance',
#  'business',
#  'despite',
#  'broad',
#  'economic',
#  'weakness',
#  'annuity',
#  'portion',
#  'volume',
#  'license',
#  'business',
#  'remain',
#  'healthy',
#  'increase',
#  'one',
#  'percentage',
#  'point',
#  'billing',
#  'mix',
#  'enterprise',
#  'agreement',
#  'renewal',
#  'rate',
#  'line',
#  'historical',
#  'trend',
#  'unearned',
#  'revenue',
#  'grow',
#  'billion',
#  'sequentially',
#  'contract',
#  'billed',
#  'balance',
#  'increase',
#  'year',
#  'year',
#  'slightly',
#  'sequential',
#  'basis',
#  'remain',
#  'billion',
#  'take',
#  'together',
#  'report',
#  'revenue',
#  'total',
#  'booking',
#  'company',
#  'decline',
#  'quarter',
#  'reflect',
#  'general',
#  'economic',
#  'weakness',
#  'primarily',
#  'nonannuity',
#  'business',
#  'overall',
#  'change',
#  'foreign',
#  'exchange',
#  'rate',
#  'add',
#  'percentage',
#  'point',
#  'revenue',
#  'growth',
#  'provide',
#  'revenue',
#  'detail',
#  'business',
#  'segment',
#  'start',
#  'window',
#  'client',
#  'client',
#  'revenue',
#  'decline',
#  'billion',
#  'review',
#  'main',
#  'driver',
#  'contribute',
#  'performance',
#  'begin',
#  'overview',
#  'pc',
#  'market',
#  'estimate',
#  'pc',
#  'market',
#  'quarter',
#  'approximately',
#  'flat',
#  'year',
#  'year',
#  'well',
#  'short',
#  'forecast',
#  'growth',
#  'pc',
#  'market',
#  'weaken',
#  'much',
#  'quickly',
#  'severely',
#  'expect',
#  'adding',
#  'bit',
#  'color',
#  'traditional',
#  'pc',
#  'decline',
#  'almost',
#  'weakness',
#  'consumer',
#  'business',
#  'pc',
#  'partially',
#  'offset',
#  'incremental',
#  'growth',
#  'new',
#  'net',
#  'book',
#  'category',
#  'quarter',
#  'window',
#  'oem',
#  'license',
#  'unit',
#  'decline',
#  'oem',
#  'revenue',
#  'lower',
#  'year',
#  'year',
#  'drive',
#  'primarily',
#  'dynamic',
#  'underlie',
#  'pc',
#  'market',
#  'specifically',
#  'decline',
#  'traditional',
#  'pc',
#  'sale',
#  'drove',
#  'double',
#  'digit',
#  'decline',
#  'business',
#  'consumer',
#  'premium',
#  'skus',
#  'copyright',
#  'sp',
#  'global',
#  'market',
#  'intelligence',
#  'division',
#  'sp',
#  'global',
#  'inc',
#  'right',
#  'reserve',
#  'spglobalcommarketintelligence',
#  'microsoft',
#  'corporation',
#  'earnings',
#  'call',
#  'jan',
#  'impact',
#  'partially',
#  'offset',
#  'growth',
#  'net',
#  'book',
#  'offer',
#  'attach',
#  'rate',
#  'pressure',
#  'quarter',
#  'experience',
#  'material',
#  'change',
#  'versus',
#  'historical',
#  'rate',
#  'net',
#  'book',
#  'attach',
#  'rate',
#  'exceed',
#  'customer',
#  'clearly',
#  'opt',
#  'value',
#  'window',
#  'provide',
#  'estimate',
#  'lose',
#  'two',
#  'percentage',
#  'point',
#  'growth',
#  'due',
#  'channel',
#  'hold',
#  'low',
#  'historical',
#  'level',
#  'inventory',
#  'commercial',
#  'retail',
#  'portion',
#  'client',
#  'business',
#  'grow',
#  'benefit',
#  'continued',
#  'adoption',
#  'window',
#  'vista',
#  'enterprise',
#  'product',
#  'front',
#  'engineering',
#  'team',
#  'reach',
#  'major',
#  'milestone',
#  'delivery',
#  'public',
#  'beta',
#  'window',
#  'receive',
#  'great',
#  'review',
#  'today',
#  'remain',
#  'positive',
#  'client',
#  'product',
#  'pipeline',
#  'inability',
#  'drive',
#  'longterm',
#  'growth',
#  'server',
#  'tool',
#  'revenue',
#  'grow',
#  'billion',
#  'despite',
#  'decline',
#  'server',
#  'hardware',
#  'market',
#  'achievement',
#  'mark',
#  'business',
#  'consecutive',
#  'quarter',
#  'doubledigit',
#  'growth',
#  'annuity',
#  'licensing',
#  'continue',
#  'grow',
#  'faster',
#  'non',
#  'annuity',
#  'license',
#  'momentum',
#  'sql',
#  'server',
#  'hyperv',
#  'visualization',
#  'help',
#  'drive',
#  'window',
#  'server',
#  'sale',
#  'increase',
#  'system',
#  'center',
#  'management',
#  'tool',
#  'attach',
#  'rate',
#  'thus',
#  'allow',
#  'grow',
#  'revenue',
#  'per',
#  'server',
#  'result',
#  'server',
#  'tool',
#  'continued',
#  'grow',
#  'faster',
#  'hardware',
#  'market',
#  'demand',
#  'consult',
#  'support',
#  'service',
#  'deploy',
#  'microsoft',
#  'technology',
#  'remain',
#  'drive',
#  'revenue',
#  'growth',
#  'product',
#  'side',
#  'server',
#  'tool',
#  'business',
#  'division',
#  'make',
#  'significant',
#  'product',
#  'development',
#  'progress',
#  'release',
#  'beta',
#  'window',
#  'server',
#  'add',
#  'live',
#  'migration',
#  'feature',
#  'hyperv',
#  'enhance',
#  'visualization',
#  'offer',
#  'professional',
#  'developer',
#  'conference',
#  'october',
#  'provide',
#  'preview',
#  'window',
#  'azure',
#  'cloud',
#  'base',
#  'service',
#  'platform',
#  'azure',
#  'service',
#  'platform',
#  'host',
#  'microsoft',
#  'data',
#  'center',
#  'provide',
#  'operate',
#  'system',
#  'set',
#  'developer',
#  'service',
#  'use',
#  'build',
#  'new',
#  'application',
#  'run',
#  'cloud',
#  'enhance',
#  'exist',
#  'application',
#  'cloud',
#  'base',
#  'capability',
#  'architecture',
#  'give',
#  'developer',
#  'choice',
#  ...]

# %% [markdown]
# ### Remove people's names

# %%
person_name_dict = {}
for tscript in msft_earnings_dict2.keys():
    msft_earnings_dict2[tscript] = [word for word, tag in pos_tag(msft_earnings_dict2[tscript]) if tag!='NNP' or word=='subscriber' or word=='xbox']
#     person_name_dict[tscript] = [word for word, tag in pos_tag(msft_earnings_dict2[tscript]) if tag=='NNP']

# %% [markdown]
# ### Remove frequent words that have no information value

# %%
frequent_words = ['quarter', 'revenue', 'microsoft', 'year', 'window', 'business', 'so', 'think', 'call', 'see',
                  'pa', 'go', 'earnings', 'question', 'fiscal', 'operator', 'billion', 'inc', 'like', 'also', 'look',
                  'good', 'come', 'well', 'get', 'say', 'make', 'right', 'chris', 'copyright', 'expect', 'use', 
                  'next', 'corporation', 'would', 'give', 'weve', 'saw', 'im', 'chief', 'officer', 'today', 'yes',
                  'investor', 'relation', 'release', 'thing', 'spglobalcommarketintelligence', 'could', 'lot', 'let',
                  'result', 'one', 'talk', 'really', 'want', 'million', 'thank', 'thanks', 'first', 'second', 'grow',
                  'growth', 'market', 'point', 'last', 'global', 'within', 'us', 'satya', 'across', 'line', 'point'
                  'even', 'up', 'include', 'cfo', 'overall', 'way', 'take', 'around', 'due', 'division', 'continue',
                  'liddle', 'server', 'presentation', 'welcome', 'jan', 'apr', 'jul', 'oct', 'third', 'fourth', 
                  'conference', 'instruction', 'my', 'turn', 'record', 'participant', 'colleen', 'healy', 'general',
                  'manager', 'bill', 'koefoed', 'may', 'sir', 'please', 'objection', 'disconnect', 'greeting',
                  'reminder', 'mike', 'spencer', 'pleasure', 'host', 'suh', 'proceed', 'afternoon', 'still', 'till',
                  'della', 'amy', 'hood', 'peter', 'klein', 'adam', 'cio', 'ceo', 'likely', 'it', 'hi', 'john',
                  'feel', 'much', 'wwwmicrosoftcommsft', 'alan', 'karl', 'ian', 'says', 'keith', 'difucci', 'steve',
                  'pc', 'sp', 'liddell', 'nadella', 'charlie', 'william', 'vice', 'president', 'ubs', 'bellini',
                  'holt', 'lync', 'fy', 'director', 'deutsche', 'keirstead', 'christopher', 'join', 'jason', 'frank',
                  'brod', 'michael', 'financial', 'increase', 'constant', 'currency', 'intelligence','former',
                  'charge', 'guarantee', 'three', 'tech', 'client','friar','senior','corporate','accounting','deputy',
                  'counsel','vp','six','five','four','sara','breza', 'db', 'ross', 'wei', 'seethoff','research',
                  'maguire', 'sarah', 'inaudible', 'mbd', 'japan', 'intelligent', 'xp', 'oppenheimer', 'ive', 'ag', 
                  'fx', 'thill', 'citigroup', 'egbert']

msft_earnings_dict3 = {}

for tscript in msft_earnings_dict2.keys():
    msft_earnings_dict3[tscript] = [word for word in msft_earnings_dict2[tscript] if word not in frequent_words]

# %% [markdown]
# ## Pickle the Dictionary of Documents (Corpus)

# %%
import pickle

# %%
with open('cleaned_corpus.pickle', 'wb') as file:
    pickle.dump(msft_earnings_dict3, file)

# %% [markdown]
# ## Bigrams

# %%
from nltk.util import ngrams

# %%
msft_earnings_dict_bi = {}

for tscript in msft_earnings_dict2.keys():
    msft_earnings_dict_bi[tscript] = [word1 + ' ' + word2 for word1, word2 in list(ngrams(msft_earnings_dict2[tscript], 2))]

# %%
### Remove frequent words that have no information value

frequent_words_bi = ['former chief','peter klein','klein former','chris liddell','call oct','call jul','call jan',
                  'call apr','officer yes','full fiscal','former general','william koefoed','koefoed former',
                  'amy hood','hood executive','executive vp','vp cfo','point view','colleen healy',
                  'christopher liddell','year year','question please','division peter','bellini ubs','chris suh',
                  'please operator','spencer general','michael spencer','rbc capital','macmillan rbc',
                  'first quarter','fourth quarter','second quarter','third quarter','tech guarantee','satya nadella',
                  'sp global','constant currency','ceo director','nadella ceo','bill koefoed','microsoft business',
                  'business division','division revenue','increase constant','grow constant','business pc',
                  'currency drive','business process','quarter full','segment gross','personal computing','suh general',
                  'director yes','friar goldman','percentage point','currency gross','cloud gross','dollar increase',
                  'point yearoveryear','officer thanks','thill citigroup']

for tscript in msft_earnings_dict_bi.keys():
    msft_earnings_dict_bi[tscript] = [word for word in msft_earnings_dict_bi[tscript] if word not in frequent_words_bi]

# %%
with open('cleaned_corpus_bi.pickle', 'wb') as file:
    pickle.dump(msft_earnings_dict_bi, file)
